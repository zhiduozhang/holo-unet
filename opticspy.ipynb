# %%
import opticspy

# %%
circle_aperture = opticspy.aperture.Circle(d=300,D=0.005)
circle_aperture.show()
# Out:
# ---------show aperture--------

# %%
circle_aperture.fresnel(z=4)
# Out:
# ---------Fresnel Diffraction----------
# Fresnel number =  21.306818181818187
# 0

# %%
circle_aperture.fraunhofer()
# Out:
# ---------Fraunhofer Diffraction----------
# 0

# %%
circle_aperture.otf()
# Out:
# -------------OTF---------------
# 0

# %%
circle_aperture
